# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
conflicts = pd.read_csv('conflicts.csv')  
#conflicts['year'] =  pd.to_datetime(conflicts['year'],format= '%Y')
conflicts = conflicts.drop(['side_a_2nd','side_b_2nd','incompatibility','ep_end_prec',
                'gwno_a','gwno_a_2nd','gwno_b','gwno_b_2nd','gwno_loc',
                'version', 'start_prec','start_date2',
                'start_prec2','ep_end','ep_end_date','territory_name',
                'intensity_level','cumulative_intensity','type_of_conflict','region','conflict_id','side_a_id','side_b_id'], axis=1)


conflicts= conflicts.sort_values(by=['year'])
conflicts.head()
# Out:
#                   location                               side_a  \
# 151                Bolivia                Government of Bolivia
# 273       France, Thailand                 Government of France
# 268  Russia (Soviet Union)  Government of Russia (Soviet Union)
# 265  Russia (Soviet Union)  Government of Russia (Soviet Union)
# 264  Russia (Soviet Union)  Government of Russia (Soviet Union)
#
#                              side_b  year  start_date
# 151  Popular Revolutionary Movement  1946  1946-07-18
# 273          Government of Thailand  1946  1946-05-07
# 268                             UPA  1946  1941-12-31
# 265                            BDPS  1946  1946-06-30
# 264                   LNPA, LTS(p)A  1946  1945-12-31

# %%
conflicts = conflicts.groupby(['side_a','year']).sum()
pd.set_option('display.max_rows', None)

conflicts
# Out:
#                                                                                                   location  \
# side_a                                             year
# Government of Afghanistan                          1978                                        Afghanistan
#                                                    1979      AfghanistanAfghanistan, Russia (Soviet Union)
#                                                    1980                                        Afghanistan
#                                                    1981                                        Afghanistan
#                                                    1982                                        Afghanistan
#                                                    1983                                        Afghanistan
#                                                    1984                                        Afghanistan
# ...
